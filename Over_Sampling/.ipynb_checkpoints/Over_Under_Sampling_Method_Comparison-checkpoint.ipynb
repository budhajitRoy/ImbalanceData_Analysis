# %% [markdown]
# ## Over and Under Sampling Methods comparison
#
# - We will try to compare various over-under sampling methods with different datasets
# - We will be using a random forest model to fit and evaluate the performance based on the Original and Resampled Data

# %%
# import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score

from imblearn.datasets import fetch_datasets

from imblearn.under_sampling import EditedNearestNeighbours, TomekLinks
from imblearn.over_sampling import (
    SMOTE,
    SVMSMOTE,
    BorderlineSMOTE
)

from imblearn.combine import SMOTEENN, SMOTETomek

# %%
# first lets set up a dictionary that contains all the over samplers

oversampler_dict = {

    'smote' : SMOTE(sampling_strategy='auto',
                    k_neighbors=5,
                    random_state=0,
                    n_jobs=2),
    
    'bd_smote_1' : BorderlineSMOTE(sampling_strategy='auto',
                                   k_neighbors=5,
                                   m_neighbors=10,
                                   kind='borderline-1',
                                   random_state=0),
    
    'svm' : SVMSMOTE(sampling_strategy='auto',
                     svm_estimator=SVC(kernel='linear', random_state=0),
                     m_neighbors=10,
                     n_jobs=2,
                     k_neighbors=5,
                     random_state=0),
    
    'smenn': SMOTEENN(
        sampling_strategy='auto',
        random_state=0,
        smote=SMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5),
        enn=EditedNearestNeighbours(
            sampling_strategy='auto', n_neighbors=3, kind_sel='all'),
        n_jobs=4),

    'smtomek': SMOTETomek(
        sampling_strategy='auto',
        random_state=0,
        smote=SMOTE(sampling_strategy='auto', random_state=0, k_neighbors=5),
        tomek=TomekLinks(sampling_strategy='all'),
        n_jobs=4),
}

# %%
# lets define the datasets in a list
datasets_ls = [
    'car_eval_34',
    'ecoli',
    'thyroid_sick',
    'arrhythmia',
    'ozone_level'
]

# %%
# lets get the datasets and see the balance ratio of each one of them

from collections import Counter

for dataset in datasets_ls:
    print(dataset)
    data = fetch_datasets()[dataset]
    print(Counter(data.target))
# Out:
# car_eval_34
# Counter({-1: 1594, 1: 134})
# ecoli
# Counter({-1: 301, 1: 35})
# thyroid_sick
# Counter({-1: 3541, 1: 231})
# arrhythmia
# Counter({-1: 427, 1: 25})
# ozone_level
# Counter({-1: 2463, 1: 73})

# %% [markdown]
# ## RF Training and evaluation

# %%
# lets create a function to run our Model
# this returns the roc auc score of the test data
def run_model(X_train, X_test, y_train, y_test):
    
    rf = RandomForestClassifier(n_estimators=100, max_depth=4, random_state=39)
    
    # fit the model on the train set
    rf.fit(X_train, y_train)
    
    # get predictions 
    
    train_preds = rf.predict_proba(X_train)[:,1]
    test_preds = rf.predict_proba(X_test)[:,1]
    # get metrics
    print('Training Data roc_auc :  {}'.format(roc_auc_score(y_train, train_preds)))
    print('Test Data roc_auc :  {}'.format(roc_auc_score(y_test, test_preds)))
    print()
    return roc_auc_score(y_test, test_preds)

# %%
# for all datasets including the original data
# lets call the function for all over samplers.
# store the results in a dictionary so that we can use to plot them to analyze


# first initialize dictionary to store the results and the size of the resampled or original data
results_dict = dict()
shapes_dict = dict()

for dataset in datasets_ls:
    print(dataset)
    results_dict[dataset] = {}
    shapes_dict[dataset] = {}
    
    data = fetch_datasets()[dataset]
    X = data.data
    y = data.target
    
    # split the data into train and test set
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=39)
    
    # as some oversampling techniques use KNN
    # we set variables in the same scale
    scaler = MinMaxScaler().fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    
    #print(X_train.shape, y_train.shape)
    
    results = run_model(X_train, X_test, y_train, y_test)
    results_dict[dataset]['full_data'] = results
    shapes_dict[dataset]['full_data'] = len(X_train)
    
    for sampler in oversampler_dict.keys():
        # fit and resample using the oversampler
        X_res, y_res = oversampler_dict[sampler].fit_resample(X_train, y_train)
        
        print(sampler)
        test_result = run_model(X_res, X_test, y_res, y_test)
        results_dict[dataset][sampler] = test_result
        shapes_dict[dataset][sampler] = len(X_res)
# Out:
# car_eval_34
# Training Data roc_auc :  0.9910989322498346
# Test Data roc_auc :  0.9888888888888889
#
# smote
# Training Data roc_auc :  0.9975310154102028
# Test Data roc_auc :  0.9939636752136751
#
# bd_smote_1
# Training Data roc_auc :  0.9989161931222985
# Test Data roc_auc :  0.9959401709401708
#
# svm
# Training Data roc_auc :  0.9980265850977764
# Test Data roc_auc :  0.9921474358974358
#
# smenn
# Training Data roc_auc :  0.9976913704798405
# Test Data roc_auc :  0.9938034188034188
#
# smtomek
# Training Data roc_auc :  0.9975310154102028
# Test Data roc_auc :  0.9939636752136751
#
# ecoli
# Training Data roc_auc :  0.9950312845049688
# Test Data roc_auc :  0.9541062801932367
#
# smote
# Training Data roc_auc :  0.9896064650534557
# Test Data roc_auc :  0.9734299516908214
#
# bd_smote_1
# Training Data roc_auc :  0.9892630663217418
# Test Data roc_auc :  0.9516908212560387
#
# svm
# Training Data roc_auc :  0.9913921384583686
# Test Data roc_auc :  0.966183574879227
#
# smenn
# Training Data roc_auc :  0.9885777277418144
# Test Data roc_auc :  0.9722222222222222
#
# smtomek
# Training Data roc_auc :  0.9890671227810651
# Test Data roc_auc :  0.9746376811594203
#
# thyroid_sick
# Training Data roc_auc :  0.9807740212636634
# Test Data roc_auc :  0.9857390213642004
#
# smote
# Training Data roc_auc :  0.9830265822694106
# Test Data roc_auc :  0.9807354084011617
#
# bd_smote_1
# Training Data roc_auc :  0.9901132386307008
# Test Data roc_auc :  0.984573329515863
#
# svm
# Training Data roc_auc :  0.9887430697645332
# Test Data roc_auc :  0.9786767011602383
#
# smenn
# Training Data roc_auc :  0.9872629032306418
# Test Data roc_auc :  0.9809944510341254
#
# smtomek
# Training Data roc_auc :  0.9836483338308145
# Test Data roc_auc :  0.9788403070336891
#
# arrhythmia
# Training Data roc_auc :  1.0
# Test Data roc_auc :  0.832051282051282
#
# smote
# Training Data roc_auc :  1.0
# Test Data roc_auc :  0.8615384615384616
#
# bd_smote_1
# Training Data roc_auc :  1.0
# Test Data roc_auc :  0.858974358974359
#
# svm
# Training Data roc_auc :  1.0
# Test Data roc_auc :  0.841025641025641
#
# smenn
# Training Data roc_auc :  0.9999886632883266
# Test Data roc_auc :  0.9038461538461537
#
# smtomek
# Training Data roc_auc :  1.0
# Test Data roc_auc :  0.8615384615384616
#
# ozone_level
# Training Data roc_auc :  0.9951089495232599
# Test Data roc_auc :  0.8793636765355722
#
# smote
# Training Data roc_auc :  0.9927439550439535
# Test Data roc_auc :  0.8820592134334952
#
# bd_smote_1
# Training Data roc_auc :  0.998299197979282
# Test Data roc_auc :  0.8566504639858595
#
# svm
# Training Data roc_auc :  0.9973199730571176
# Test Data roc_auc :  0.864516129032258
#
# smenn
# Training Data roc_auc :  0.9935906934031324
# Test Data roc_auc :  0.8843128590366769
#
# smtomek
# Training Data roc_auc :  0.9927439550439535
# Test Data roc_auc :  0.8820592134334952

# %%
results_dict, shapes_dict
# Out:
# ({'car_eval_34': {'full_data': 0.9888888888888889,
#    'smote': 0.9939636752136751,
#    'bd_smote_1': 0.9959401709401708,
#    'svm': 0.9921474358974358,
#    'smenn': 0.9938034188034188,
#    'smtomek': 0.9939636752136751},
#   'ecoli': {'full_data': 0.9541062801932367,
#    'smote': 0.9734299516908214,
#    'bd_smote_1': 0.9516908212560387,
#    'svm': 0.966183574879227,
#    'smenn': 0.9722222222222222,
#    'smtomek': 0.9746376811594203},
#   'thyroid_sick': {'full_data': 0.9857390213642004,
#    'smote': 0.9807354084011617,
#    'bd_smote_1': 0.984573329515863,
#    'svm': 0.9786767011602383,
#    'smenn': 0.9809944510341254,
#    'smtomek': 0.9788403070336891},
#   'arrhythmia': {'full_data': 0.832051282051282,
#    'smote': 0.8615384615384616,
#    'bd_smote_1': 0.858974358974359,
#    'svm': 0.841025641025641,
#    'smenn': 0.9038461538461537,
#    'smtomek': 0.8615384615384616},
#   'ozone_level': {'full_data': 0.8793636765355722,
#    'smote': 0.8820592134334952,
#    'bd_smote_1': 0.8566504639858595,
#    'svm': 0.864516129032258,
#    'smenn': 0.8843128590366769,
#    'smtomek': 0.8820592134334952}},
#  {'car_eval_34': {'full_data': 1209,
#    'smote': 2228,
#    'bd_smote_1': 2228,
#    'svm': 2228,
#    'smenn': 2228,
#    'smtomek': 2228},
#   'ecoli': {'full_data': 235,
#    'smote': 418,
#    'bd_smote_1': 418,
#    'svm': 418,
#    'smenn': 413,
#    'smtomek': 416},
#   'thyroid_sick': {'full_data': 2640,
#    'smote': 4956,
#    'bd_smote_1': 4956,
#    'svm': 4956,
#    'smenn': 4901,
#    'smtomek': 4944},
#   'arrhythmia': {'full_data': 316,
#    'smote': 594,
#    'bd_smote_1': 594,
#    'svm': 482,
#    'smenn': 594,
#    'smtomek': 594},
#   'ozone_level': {'full_data': 1775,
#    'smote': 3466,
#    'bd_smote_1': 3466,
#    'svm': 2785,
#    'smenn': 3466,
#    'smtomek': 3466}})

# %%
# now lets plot these results_dict using a bar plot

for dataset in datasets_ls:
    pd.Series(results_dict[dataset]).plot.bar()
    
    plt.axhline(results_dict[dataset]['full_data'], c = 'red')
    plt.title(dataset)
    plt.ylabel('roc_auc_score')
    plt.show()

# %%
# now lets plot these results_dict using a bar plot
# zooming the ylim value from 0.8 to 1

for dataset in datasets_ls:
    pd.Series(results_dict[dataset]).plot.bar()
    plt.ylim(0.8,1)
    plt.title(dataset)
    plt.ylabel('roc_auc_score')
    plt.axhline(results_dict[dataset]['full_data'], c = 'red')
    plt.show()

# %% [markdown]
# **So, we can see that different over sampling techniques work better and different in different datasets**
# - In the arrhythmia dataset, the combined under and over sampling seems to work better than just SMOTE and any other technique. This, however varies with the dataset we work with.
# - So, probably we might need to try few techniques based on the nature of the dataset and will need to find the best one that our model best performs with

# %%
# plotting the shapes

for dataset in datasets_ls:
    pd.Series(shapes_dict[dataset]).plot.bar()
    plt.title(dataset)
    plt.show()
